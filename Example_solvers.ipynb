# %% [markdown]
# # Simple Cantilever Beam Example

# %% [markdown]
# ## Required Imports

# %%
from fem2d.meshers import Mesh, Q8Mesh
from fem2d.solvers import FEMSolvers
from fem2d.postprocessing import Plotting

# %% [markdown]
# ## Problem Set Up

# %%
E = 210000 #youngs modulous
v = 0.3 #possions ratio
t = 1 #thickness
plane = 1 #plane strain or plain stress
ELtype = 'Q4' #Element type

Beam = Mesh(E, v, t, plane, ELtype) #Create mesh object

el_num = 20
Length = 10
thickness = 0.5
Load = -25

Beam.SimpleBeam(el_num, Length, thickness, Load) #Create a simple cantilever beam

# %% [markdown]
# ## View Created Mesh

# %%
#All plotting functions return the ax object.
ax = Plotting.InitialMesh(Beam)
# Plotting.ProblemDiagram(Beam) <- this will include node numbers.

# %% [markdown]
# ## Simulate Problem

# %%
# solvers return the displacement vector
U = FEMSolvers.LinearSolver(Beam)
ax = Plotting.Overlay(Beam)

# %% [markdown]
# ### The same mesh object can be used with all the solvers

# %%
U = FEMSolvers.NonLinearSolver(Beam, LoadSteps=3, tol = 1e-2)
ax = Plotting.Overlay(Beam, steps=1)
ax = Plotting.LoadPath(Beam)
# Out:
# ---------------
# Load Step 1
# ---------------
# Interation 0, Residual Norm 1.0
# Interation 1, Residual Norm 595.0931476981226
# Interation 2, Residual Norm 4.537125809300863
# Interation 3, Residual Norm 0.0063467353995522845
# ---------------
# Load Step 2
# ---------------
# Interation 0, Residual Norm 1.0
# Interation 1, Residual Norm 590.4191484676555
# Interation 2, Residual Norm 4.471297109047902
# Interation 3, Residual Norm 0.03319192300528918
# Interation 4, Residual Norm 0.0007262968613006644
# ---------------
# Load Step 3
# ---------------
# Interation 0, Residual Norm 1.0
# Interation 1, Residual Norm 557.0856160360805
# Interation 2, Residual Norm 3.9859406562557886
# Interation 3, Residual Norm 0.1606015165112408
# Interation 4, Residual Norm 0.002696743732349492

# %%
U = FEMSolvers.ArcLengthSolver(Beam, ArcLength=2, TotalArcLength=6, tol = 1e-2)
ax = Plotting.Overlay(Beam, steps=1)
# Out:
# -----------------------
# Accumalted Arc Length 0
# -----------------------
# Itertion 0, ResNorm 1.0
# Itertion 1, ResNorm 498.9625228796131
# Itertion 2, ResNorm 2.699623593195248
# Itertion 3, ResNorm 0.0019565537189469464
# -----------------------
# Accumalted Arc Length 2
# -----------------------
# Itertion 0, ResNorm 1.0
# Itertion 1, ResNorm 498.5676449631683
# Itertion 2, ResNorm 2.7039904710562275
# Itertion 3, ResNorm 0.0013194101787810377
# -----------------------
# Accumalted Arc Length 4
# -----------------------
# Itertion 0, ResNorm 1.0
# Itertion 1, ResNorm 488.8249691043675
# Itertion 2, ResNorm 2.6511104798366056
# Itertion 3, ResNorm 0.0007890528262375295

# %% [markdown]
# ## View Results
#
# ### The results are stored in the mesh. attributes

# %%
Beam.U
Beam.LoadValues
# Out:
# array([0.        , 0.27987023, 0.56284752, 0.85397942])

# %% [markdown]
# ## Q8 Set Up

# %%
E = 210000 #youngs modulous
v = 0.3 #possions ratio
t = 1 #thickness
plane = 1 #plane strain or plain stress
ELtype = 'Q8' #Element type

Beam = Q8Mesh(E, v, t, plane, ELtype) #Create mesh object with Q8 meshers

el_num = 20
Length = 10
thickness = 0.5
Load = -25

Beam.SimpleBeam(el_num, Length, thickness, Load) #Create a simple cantilever beam

# %%
U = FEMSolvers.NonLinearSolver(Beam, LoadSteps=3, tol = 1e-2)
ax = Plotting.Overlay(Beam, steps=1)
# Out:
# ---------------
# Load Step 1
# ---------------
# Interation 0, Residual Norm 1.0
# Interation 1, Residual Norm 1139.2284973972473
# Interation 2, Residual Norm 21.05206725984933
# Interation 3, Residual Norm 0.01936138183965834
# Interation 4, Residual Norm 0.010776339933147975
# Interation 5, Residual Norm 1.500621652542017e-08
# ---------------
# Load Step 2
# ---------------
# Interation 0, Residual Norm 1.0
# Interation 1, Residual Norm 1099.6928418415157
# Interation 2, Residual Norm 19.677260109566564
# Interation 3, Residual Norm 0.14195787804410642
# Interation 4, Residual Norm 0.1964776394412698
# Interation 5, Residual Norm 1.704559810334268e-05
# ---------------
# Load Step 3
# ---------------
# Interation 0, Residual Norm 1.0
# Interation 1, Residual Norm 944.3300294939847
# Interation 2, Residual Norm 14.61168944676877
# Interation 3, Residual Norm 0.5664123602643069
# Interation 4, Residual Norm 0.41203984558788476
# Interation 5, Residual Norm 0.0004917941308718207
